# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 727

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint-pierre
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | touros
# Processing Record 4 of Set 1 | kannur
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | batagay-alyta
# Processing Record 7 of Set 1 | nanakuli
# Processing Record 8 of Set 1 | saskylakh
# Processing Record 9 of Set 1 | clyde river
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | jalu
# Processing Record 12 of Set 1 | ponta delgada
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | leningradskiy
# Processing Record 18 of Set 1 | ambatondrazaka
# Processing Record 19 of Set 1 | tasiilaq
# Processing Record 20 of Set 1 | isangel
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | carnarvon
# Processing Record 23 of Set 1 | east london
# Processing Record 24 of Set 1 | richards bay
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | bengkulu
# Processing Record 28 of Set 1 | nikolskoye
# Processing Record 29 of Set 1 | bambous virieux
# Processing Record 30 of Set 1 | belaya gora
# Processing Record 31 of Set 1 | komsomolskiy
# Processing Record 32 of Set 1 | castro
# Processing Record 33 of Set 1 | kodiak
# Processing Record 34 of Set 1 | barcelos
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | pevek
# Processing Record 37 of Set 1 | klaksvik
# Processing Record 38 of Set 1 | makokou
# Processing Record 39 of Set 1 | ust-kulom
# Processing Record 40 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 41 of Set 1 | lasa
# Processing Record 42 of Set 1 | norman wells
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | zhanakorgan
# Processing Record 45 of Set 1 | kisangani
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | amapa
# Processing Record 48 of Set 1 | buala
# Processing Record 49 of Set 1 | chuy
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | cabo san lucas
# Processing Record 2 of Set 2 | hamilton
# Processing Record 3 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 2 | pimenteiras
# Processing Record 5 of Set 2 | thompson
# Processing Record 6 of Set 2 | mataura
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | lagoa
# Processing Record 10 of Set 2 | sai buri
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | lufilufi
# Processing Record 13 of Set 2 | barrow
# Processing Record 14 of Set 2 | timbiqui
# Processing Record 15 of Set 2 | mount gambier
# Processing Record 16 of Set 2 | margate
# Processing Record 17 of Set 2 | albanel
# Processing Record 18 of Set 2 | fortuna
# Processing Record 19 of Set 2 | ksenyevka
# City not found. Skipping...
# Processing Record 20 of Set 2 | boende
# Processing Record 21 of Set 2 | knyaginino
# Processing Record 22 of Set 2 | fundacion
# Processing Record 23 of Set 2 | porto novo
# Processing Record 24 of Set 2 | baykit
# Processing Record 25 of Set 2 | makakilo city
# Processing Record 26 of Set 2 | mandal
# Processing Record 27 of Set 2 | pamanukan
# Processing Record 28 of Set 2 | marsabit
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | hobart
# Processing Record 31 of Set 2 | boden
# Processing Record 32 of Set 2 | mar del plata
# Processing Record 33 of Set 2 | orlik
# Processing Record 34 of Set 2 | aldan
# Processing Record 35 of Set 2 | husavik
# Processing Record 36 of Set 2 | longyearbyen
# Processing Record 37 of Set 2 | ancud
# Processing Record 38 of Set 2 | esperance
# Processing Record 39 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 2 | hilo
# Processing Record 41 of Set 2 | oktyabrskiy
# Processing Record 42 of Set 2 | salalah
# Processing Record 43 of Set 2 | namibe
# Processing Record 44 of Set 2 | srednekolymsk
# Processing Record 45 of Set 2 | naze
# Processing Record 46 of Set 2 | hualmay
# Processing Record 47 of Set 2 | sao joao da barra
# Processing Record 48 of Set 2 | pangnirtung
# Processing Record 49 of Set 2 | bluff
# Processing Record 50 of Set 2 | souillac
# Processing Record 1 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 3 | ust-tsilma
# Processing Record 3 of Set 3 | kita
# Processing Record 4 of Set 3 | terrace
# Processing Record 5 of Set 3 | khatanga
# Processing Record 6 of Set 3 | blythe
# Processing Record 7 of Set 3 | yellowknife
# Processing Record 8 of Set 3 | iqaluit
# Processing Record 9 of Set 3 | dwarka
# Processing Record 10 of Set 3 | avera
# Processing Record 11 of Set 3 | bielsk podlaski
# Processing Record 12 of Set 3 | kruisfontein
# Processing Record 13 of Set 3 | vaini
# Processing Record 14 of Set 3 | kavieng
# Processing Record 15 of Set 3 | tezu
# Processing Record 16 of Set 3 | los llanos de aridane
# Processing Record 17 of Set 3 | avarua
# Processing Record 18 of Set 3 | santa cruz de tenerife
# Processing Record 19 of Set 3 | bathsheba
# Processing Record 20 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 3 | vila velha
# Processing Record 22 of Set 3 | faanui
# Processing Record 23 of Set 3 | banmo
# City not found. Skipping...
# Processing Record 24 of Set 3 | lashio
# Processing Record 25 of Set 3 | port hedland
# Processing Record 26 of Set 3 | torbay
# Processing Record 27 of Set 3 | ixil
# Processing Record 28 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 3 | ilulissat
# Processing Record 30 of Set 3 | sur
# Processing Record 31 of Set 3 | cayenne
# Processing Record 32 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 3 | barcelona
# Processing Record 34 of Set 3 | vostok
# Processing Record 35 of Set 3 | cape town
# Processing Record 36 of Set 3 | yamethin
# Processing Record 37 of Set 3 | hofn
# Processing Record 38 of Set 3 | port macquarie
# Processing Record 39 of Set 3 | jian
# Processing Record 40 of Set 3 | bergama
# Processing Record 41 of Set 3 | concordia
# Processing Record 42 of Set 3 | provideniya
# Processing Record 43 of Set 3 | caravelas
# Processing Record 44 of Set 3 | coihaique
# Processing Record 45 of Set 3 | chara
# Processing Record 46 of Set 3 | le port
# Processing Record 47 of Set 3 | nizhniy kuranakh
# Processing Record 48 of Set 3 | lebu
# Processing Record 49 of Set 3 | poum
# Processing Record 50 of Set 3 | victor harbor
# Processing Record 1 of Set 4 | miguel hidalgo
# Processing Record 2 of Set 4 | mogadishu
# Processing Record 3 of Set 4 | ossora
# Processing Record 4 of Set 4 | ballina
# Processing Record 5 of Set 4 | macroom
# Processing Record 6 of Set 4 | tiksi
# Processing Record 7 of Set 4 | araouane
# Processing Record 8 of Set 4 | odweyne
# Processing Record 9 of Set 4 | uruzgan
# Processing Record 10 of Set 4 | libreville
# Processing Record 11 of Set 4 | herat
# Processing Record 12 of Set 4 | vila franca do campo
# Processing Record 13 of Set 4 | sambava
# Processing Record 14 of Set 4 | flin flon
# Processing Record 15 of Set 4 | kaitangata
# Processing Record 16 of Set 4 | denpasar
# Processing Record 17 of Set 4 | mehamn
# Processing Record 18 of Set 4 | adrar
# Processing Record 19 of Set 4 | vao
# Processing Record 20 of Set 4 | maceio
# Processing Record 21 of Set 4 | henties bay
# Processing Record 22 of Set 4 | port elizabeth
# Processing Record 23 of Set 4 | chokurdakh
# Processing Record 24 of Set 4 | pacific grove
# Processing Record 25 of Set 4 | xining
# Processing Record 26 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 4 | okakarara
# Processing Record 28 of Set 4 | boa vista
# Processing Record 29 of Set 4 | dukat
# Processing Record 30 of Set 4 | constitucion
# Processing Record 31 of Set 4 | leira
# Processing Record 32 of Set 4 | pasighat
# Processing Record 33 of Set 4 | college station
# Processing Record 34 of Set 4 | murgab
# Processing Record 35 of Set 4 | waitati
# Processing Record 36 of Set 4 | saint-prosper
# Processing Record 37 of Set 4 | nemuro
# Processing Record 38 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 4 | ariquemes
# Processing Record 40 of Set 4 | luorong
# Processing Record 41 of Set 4 | eureka
# Processing Record 42 of Set 4 | severo-kurilsk
# Processing Record 43 of Set 4 | luderitz
# Processing Record 44 of Set 4 | kuytun
# Processing Record 45 of Set 4 | pochutla
# Processing Record 46 of Set 4 | aklavik
# Processing Record 47 of Set 4 | oskemen
# Processing Record 48 of Set 4 | buariki
# City not found. Skipping...
# Processing Record 49 of Set 4 | zagreb
# Processing Record 50 of Set 4 | okhotsk
# Processing Record 1 of Set 5 | muros
# Processing Record 2 of Set 5 | rosetta
# Processing Record 3 of Set 5 | bartica
# Processing Record 4 of Set 5 | turukhansk
# Processing Record 5 of Set 5 | lalibela
# Processing Record 6 of Set 5 | torbat-e jam
# Processing Record 7 of Set 5 | tuatapere
# Processing Record 8 of Set 5 | pervomayskoye
# Processing Record 9 of Set 5 | saldanha
# Processing Record 10 of Set 5 | atar
# Processing Record 11 of Set 5 | cidreira
# Processing Record 12 of Set 5 | sri aman
# Processing Record 13 of Set 5 | lompoc
# Processing Record 14 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 5 | olafsvik
# Processing Record 16 of Set 5 | aasiaat
# Processing Record 17 of Set 5 | kropotkin
# Processing Record 18 of Set 5 | dicabisagan
# Processing Record 19 of Set 5 | kupang
# Processing Record 20 of Set 5 | loviisa
# Processing Record 21 of Set 5 | veraval
# Processing Record 22 of Set 5 | egvekinot
# Processing Record 23 of Set 5 | puerto escondido
# Processing Record 24 of Set 5 | teguldet
# Processing Record 25 of Set 5 | cockburn town
# Processing Record 26 of Set 5 | bhilwara
# Processing Record 27 of Set 5 | ayr
# Processing Record 28 of Set 5 | laguna
# Processing Record 29 of Set 5 | filadelfia
# Processing Record 30 of Set 5 | asau
# Processing Record 31 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 5 | ponta do sol
# Processing Record 33 of Set 5 | livingston
# Processing Record 34 of Set 5 | hami
# Processing Record 35 of Set 5 | saint-philippe
# Processing Record 36 of Set 5 | vardo
# Processing Record 37 of Set 5 | san cristobal
# Processing Record 38 of Set 5 | padang
# Processing Record 39 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 5 | ginir
# Processing Record 41 of Set 5 | ahipara
# Processing Record 42 of Set 5 | biak
# Processing Record 43 of Set 5 | saint george
# Processing Record 44 of Set 5 | gamba
# Processing Record 45 of Set 5 | moindou
# Processing Record 46 of Set 5 | xuddur
# Processing Record 47 of Set 5 | hamina
# Processing Record 48 of Set 5 | kahului
# Processing Record 49 of Set 5 | makubetsu
# Processing Record 50 of Set 5 | bahia blanca
# Processing Record 1 of Set 6 | high prairie
# Processing Record 2 of Set 6 | karasjok
# Processing Record 3 of Set 6 | mutare
# Processing Record 4 of Set 6 | noyabrsk
# Processing Record 5 of Set 6 | tarasovskiy
# Processing Record 6 of Set 6 | tamiahua
# Processing Record 7 of Set 6 | hasaki
# Processing Record 8 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 6 | balkhash
# Processing Record 10 of Set 6 | yulara
# Processing Record 11 of Set 6 | luwuk
# Processing Record 12 of Set 6 | dongsheng
# Processing Record 13 of Set 6 | salvador
# Processing Record 14 of Set 6 | cherskiy
# Processing Record 15 of Set 6 | bilma
# Processing Record 16 of Set 6 | chulman
# Processing Record 17 of Set 6 | arraial do cabo
# Processing Record 18 of Set 6 | pontianak
# Processing Record 19 of Set 6 | brae
# Processing Record 20 of Set 6 | juneau
# Processing Record 21 of Set 6 | geraldton
# Processing Record 22 of Set 6 | fallon
# Processing Record 23 of Set 6 | dzilam gonzalez
# Processing Record 24 of Set 6 | pakokku
# Processing Record 25 of Set 6 | iracoubo
# Processing Record 26 of Set 6 | wani
# Processing Record 27 of Set 6 | katsuura
# Processing Record 28 of Set 6 | iralaya
# Processing Record 29 of Set 6 | kholm-zhirkovskiy
# Processing Record 30 of Set 6 | ribeira grande
# Processing Record 31 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 6 | champerico
# Processing Record 33 of Set 6 | coahuayana
# Processing Record 34 of Set 6 | kondinskoye
# Processing Record 35 of Set 6 | nioro
# Processing Record 36 of Set 6 | san patricio
# Processing Record 37 of Set 6 | koslan
# Processing Record 38 of Set 6 | grindavik
# Processing Record 39 of Set 6 | sipoo
# Processing Record 40 of Set 6 | tahoua
# Processing Record 41 of Set 6 | hohhot
# Processing Record 42 of Set 6 | mahon
# Processing Record 43 of Set 6 | ternate
# Processing Record 44 of Set 6 | upernavik
# Processing Record 45 of Set 6 | santo domingo
# Processing Record 46 of Set 6 | konotop
# Processing Record 47 of Set 6 | roswell
# Processing Record 48 of Set 6 | okato
# Processing Record 49 of Set 6 | guamuchil
# Processing Record 50 of Set 6 | fez
# Processing Record 1 of Set 7 | moree
# Processing Record 2 of Set 7 | puerto suarez
# Processing Record 3 of Set 7 | pisco
# Processing Record 4 of Set 7 | zunyi
# Processing Record 5 of Set 7 | zhuozhou
# City not found. Skipping...
# Processing Record 6 of Set 7 | makung
# City not found. Skipping...
# Processing Record 7 of Set 7 | mollendo
# Processing Record 8 of Set 7 | nishihara
# Processing Record 9 of Set 7 | wanning
# Processing Record 10 of Set 7 | port blair
# Processing Record 11 of Set 7 | mubende
# Processing Record 12 of Set 7 | tsiroanomandidy
# Processing Record 13 of Set 7 | hillsborough
# Processing Record 14 of Set 7 | palmer
# Processing Record 15 of Set 7 | ler
# Processing Record 16 of Set 7 | marv dasht
# City not found. Skipping...
# Processing Record 17 of Set 7 | haines junction
# Processing Record 18 of Set 7 | pucallpa
# Processing Record 19 of Set 7 | kysyl-syr
# Processing Record 20 of Set 7 | beringovskiy
# Processing Record 21 of Set 7 | the pas
# Processing Record 22 of Set 7 | omboue
# Processing Record 23 of Set 7 | riyadh
# Processing Record 24 of Set 7 | labuhan
# Processing Record 25 of Set 7 | kirkwood
# Processing Record 26 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 7 | erenhot
# Processing Record 28 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 29 of Set 7 | vilhena
# Processing Record 30 of Set 7 | wad rawah
# Processing Record 31 of Set 7 | nigran
# Processing Record 32 of Set 7 | port-gentil
# Processing Record 33 of Set 7 | oranienburg
# Processing Record 34 of Set 7 | bilibino
# Processing Record 35 of Set 7 | ban bung
# Processing Record 36 of Set 7 | sao jose da coroa grande
# Processing Record 37 of Set 7 | shubarkuduk
# Processing Record 38 of Set 7 | marrakesh
# Processing Record 39 of Set 7 | pandan
# Processing Record 40 of Set 7 | khatassy
# Processing Record 41 of Set 7 | narsaq
# Processing Record 42 of Set 7 | georgetown
# Processing Record 43 of Set 7 | auriflama
# Processing Record 44 of Set 7 | pasni
# Processing Record 45 of Set 7 | san quintin
# Processing Record 46 of Set 7 | konstantinovka
# Processing Record 47 of Set 7 | salym
# Processing Record 48 of Set 7 | lahij
# Processing Record 49 of Set 7 | batagay
# Processing Record 50 of Set 7 | mahebourg
# Processing Record 1 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 8 | te anau
# Processing Record 3 of Set 8 | genhe
# Processing Record 4 of Set 8 | kavaratti
# Processing Record 5 of Set 8 | qasigiannguit
# Processing Record 6 of Set 8 | murmashi
# Processing Record 7 of Set 8 | pekan
# Processing Record 8 of Set 8 | ola
# Processing Record 9 of Set 8 | tabukiniberu
# City not found. Skipping...
# Processing Record 10 of Set 8 | saryozek
# Processing Record 11 of Set 8 | muncar
# Processing Record 12 of Set 8 | mokhsogollokh
# Processing Record 13 of Set 8 | port lincoln
# Processing Record 14 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 15 of Set 8 | coihueco
# Processing Record 16 of Set 8 | guerrero negro
# Processing Record 17 of Set 8 | inirida
# Processing Record 18 of Set 8 | aras
# Processing Record 19 of Set 8 | mayumba
# Processing Record 20 of Set 8 | tuktoyaktuk
# Processing Record 21 of Set 8 | santa isabel do rio negro
# Processing Record 22 of Set 8 | sao felix do xingu
# Processing Record 23 of Set 8 | florianopolis
# Processing Record 24 of Set 8 | puerto carreno
# Processing Record 25 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 8 | kapit
# Processing Record 27 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 8 | andenes
# Processing Record 29 of Set 8 | gollere
# City not found. Skipping...
# Processing Record 30 of Set 8 | cacoal
# Processing Record 31 of Set 8 | fort nelson
# Processing Record 32 of Set 8 | farafangana
# Processing Record 33 of Set 8 | zyryanka
# Processing Record 34 of Set 8 | aksha
# Processing Record 35 of Set 8 | nouadhibou
# Processing Record 36 of Set 8 | new ulm
# Processing Record 37 of Set 8 | kuusamo
# Processing Record 38 of Set 8 | leme
# Processing Record 39 of Set 8 | portland
# Processing Record 40 of Set 8 | athens
# Processing Record 41 of Set 8 | primorka
# Processing Record 42 of Set 8 | victoria
# Processing Record 43 of Set 8 | sindou
# Processing Record 44 of Set 8 | madingou
# Processing Record 45 of Set 8 | belyy
# Processing Record 46 of Set 8 | polyarnyy
# Processing Record 47 of Set 8 | huarmey
# Processing Record 48 of Set 8 | saint-louis
# Processing Record 49 of Set 8 | opuwo
# Processing Record 50 of Set 8 | anadyr
# Processing Record 1 of Set 9 | hearst
# Processing Record 2 of Set 9 | waingapu
# Processing Record 3 of Set 9 | bud
# Processing Record 4 of Set 9 | alofi
# Processing Record 5 of Set 9 | beyneu
# Processing Record 6 of Set 9 | dandong
# Processing Record 7 of Set 9 | lajas
# Processing Record 8 of Set 9 | barbastro
# Processing Record 9 of Set 9 | terra santa
# Processing Record 10 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 9 | shizilu
# Processing Record 12 of Set 9 | dungarvan
# Processing Record 13 of Set 9 | launceston
# Processing Record 14 of Set 9 | acarau
# Processing Record 15 of Set 9 | cerritos
# Processing Record 16 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 17 of Set 9 | nyurba
# Processing Record 18 of Set 9 | hervey bay
# Processing Record 19 of Set 9 | ampanihy
# Processing Record 20 of Set 9 | kitimat
# Processing Record 21 of Set 9 | forecariah
# Processing Record 22 of Set 9 | faya
# Processing Record 23 of Set 9 | talnakh
# Processing Record 24 of Set 9 | yuxia
# Processing Record 25 of Set 9 | sistranda
# Processing Record 26 of Set 9 | kralendijk
# Processing Record 27 of Set 9 | verkhnevilyuysk
# Processing Record 28 of Set 9 | takoradi
# Processing Record 29 of Set 9 | oshawa
# Processing Record 30 of Set 9 | nizhneudinsk
# Processing Record 31 of Set 9 | punta alta
# Processing Record 32 of Set 9 | lisala
# Processing Record 33 of Set 9 | huilong
# Processing Record 34 of Set 9 | santarem
# Processing Record 35 of Set 9 | alginet
# Processing Record 36 of Set 9 | mastung
# Processing Record 37 of Set 9 | agadez
# Processing Record 38 of Set 9 | gualaquiza
# Processing Record 39 of Set 9 | mersin
# Processing Record 40 of Set 9 | nardaran
# Processing Record 41 of Set 9 | leh
# Processing Record 42 of Set 9 | codrington
# Processing Record 43 of Set 9 | jijiga
# Processing Record 44 of Set 9 | shenjiamen
# Processing Record 45 of Set 9 | bayangol
# Processing Record 46 of Set 9 | bad freienwalde
# Processing Record 47 of Set 9 | tres arroyos
# Processing Record 48 of Set 9 | port augusta
# Processing Record 49 of Set 9 | maykain
# City not found. Skipping...
# Processing Record 50 of Set 9 | la rioja
# Processing Record 1 of Set 10 | pizarro
# Processing Record 2 of Set 10 | kaura namoda
# Processing Record 3 of Set 10 | mandvi
# Processing Record 4 of Set 10 | hovd
# Processing Record 5 of Set 10 | yambio
# Processing Record 6 of Set 10 | lavrentiya
# Processing Record 7 of Set 10 | melfi
# Processing Record 8 of Set 10 | phonhong
# Processing Record 9 of Set 10 | college
# Processing Record 10 of Set 10 | port maria
# Processing Record 11 of Set 10 | krasnoselkup
# Processing Record 12 of Set 10 | nikolayevsk-na-amure
# Processing Record 13 of Set 10 | kasongo
# Processing Record 14 of Set 10 | ingham
# Processing Record 15 of Set 10 | biograd na moru
# Processing Record 16 of Set 10 | aksarka
# Processing Record 17 of Set 10 | saint-leu
# Processing Record 18 of Set 10 | buraydah
# Processing Record 19 of Set 10 | magadan
# Processing Record 20 of Set 10 | atambua
# Processing Record 21 of Set 10 | yar-sale
# Processing Record 22 of Set 10 | zanjan
# Processing Record 23 of Set 10 | beysehir
# Processing Record 24 of Set 10 | tura
# Processing Record 25 of Set 10 | rantoul
# Processing Record 26 of Set 10 | merritt island
# Processing Record 27 of Set 10 | vestmanna
# Processing Record 28 of Set 10 | kupino
# Processing Record 29 of Set 10 | sembe
# Processing Record 30 of Set 10 | banjarmasin
# Processing Record 31 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 32 of Set 10 | luganville
# Processing Record 33 of Set 10 | maneadero
# Processing Record 34 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 10 | diamantino
# Processing Record 36 of Set 10 | san juan
# Processing Record 37 of Set 10 | zabinka
# City not found. Skipping...
# Processing Record 38 of Set 10 | preobrazheniye
# Processing Record 39 of Set 10 | bachatskiy
# Processing Record 40 of Set 10 | beloha
# Processing Record 41 of Set 10 | seoul
# Processing Record 42 of Set 10 | yoichi
# Processing Record 43 of Set 10 | innisfail
# Processing Record 44 of Set 10 | turkistan
# Processing Record 45 of Set 10 | sobolevo
# Processing Record 46 of Set 10 | truro
# Processing Record 47 of Set 10 | lorengau
# Processing Record 48 of Set 10 | mountain home
# Processing Record 49 of Set 10 | tilichiki
# Processing Record 50 of Set 10 | tessalit
# Processing Record 1 of Set 11 | kamien pomorski
# Processing Record 2 of Set 11 | novaya ladoga
# Processing Record 3 of Set 11 | zarand
# Processing Record 4 of Set 11 | vestmannaeyjar
# Processing Record 5 of Set 11 | brookside
# Processing Record 6 of Set 11 | nayudupeta
# Processing Record 7 of Set 11 | dingle
# Processing Record 8 of Set 11 | kirakira
# Processing Record 9 of Set 11 | umm kaddadah
# Processing Record 10 of Set 11 | plouzane
# Processing Record 11 of Set 11 | valley city
# Processing Record 12 of Set 11 | maturin
# Processing Record 13 of Set 11 | grimshaw
# Processing Record 14 of Set 11 | jining
# Processing Record 15 of Set 11 | havelock
# Processing Record 16 of Set 11 | muromtsevo
# Processing Record 17 of Set 11 | linxia
# Processing Record 18 of Set 11 | lubumbashi
# Processing Record 19 of Set 11 | barahona
# Processing Record 20 of Set 11 | chhapra
# Processing Record 21 of Set 11 | sioux lookout
# Processing Record 22 of Set 11 | heinola
# Processing Record 23 of Set 11 | solnechnyy
# Processing Record 24 of Set 11 | taltal
# Processing Record 25 of Set 11 | itarema
# Processing Record 26 of Set 11 | nalut
# Processing Record 27 of Set 11 | anshun
# Processing Record 28 of Set 11 | serabu
# Processing Record 29 of Set 11 | sainte-suzanne
# Processing Record 30 of Set 11 | san policarpo
# Processing Record 31 of Set 11 | fukue
# Processing Record 32 of Set 11 | huron
# Processing Record 33 of Set 11 | pombas
# Processing Record 34 of Set 11 | karaidel
# Processing Record 35 of Set 11 | simao
# Processing Record 36 of Set 11 | gorontalo
# Processing Record 37 of Set 11 | sarakhs
# Processing Record 38 of Set 11 | ales
# Processing Record 39 of Set 11 | zaragoza
# Processing Record 40 of Set 11 | hambantota
# Processing Record 41 of Set 11 | bontang
# Processing Record 42 of Set 11 | pleasanton
# Processing Record 43 of Set 11 | hun
# Processing Record 44 of Set 11 | rawson
# Processing Record 45 of Set 11 | campos novos
# Processing Record 46 of Set 11 | tawang
# Processing Record 47 of Set 11 | mugur-aksy
# Processing Record 48 of Set 11 | achisay
# City not found. Skipping...
# Processing Record 49 of Set 11 | gonaives
# Processing Record 50 of Set 11 | polis
# Processing Record 1 of Set 12 | orcopampa
# Processing Record 2 of Set 12 | coquimbo
# Processing Record 3 of Set 12 | grants
# Processing Record 4 of Set 12 | saint-georges
# Processing Record 5 of Set 12 | zagan
# Processing Record 6 of Set 12 | yarmouth
# Processing Record 7 of Set 12 | mantua
# Processing Record 8 of Set 12 | axim
# Processing Record 9 of Set 12 | nelson bay
# Processing Record 10 of Set 12 | bail hongal
# Processing Record 11 of Set 12 | nantucket
# Processing Record 12 of Set 12 | tello
# Processing Record 13 of Set 12 | rio gallegos
# Processing Record 14 of Set 12 | broome
# Processing Record 15 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 16 of Set 12 | saint-joseph
# Processing Record 17 of Set 12 | siderno
# Processing Record 18 of Set 12 | sitka
# Processing Record 19 of Set 12 | ellensburg
# Processing Record 20 of Set 12 | aloleng
# Processing Record 21 of Set 12 | big bend
# Processing Record 22 of Set 12 | tombouctou
# Processing Record 23 of Set 12 | nerchinskiy zavod
# Processing Record 24 of Set 12 | mercedes
# Processing Record 25 of Set 12 | roebourne
# Processing Record 26 of Set 12 | loralai
# Processing Record 27 of Set 12 | tocopilla
# Processing Record 28 of Set 12 | ibia
# Processing Record 29 of Set 12 | gat
# Processing Record 30 of Set 12 | ust-kuyga
# Processing Record 31 of Set 12 | moose factory
# Processing Record 32 of Set 12 | mancio lima
# Processing Record 33 of Set 12 | tazovskiy
# Processing Record 34 of Set 12 | sinjar
# Processing Record 35 of Set 12 | syracuse
# Processing Record 36 of Set 12 | san jeronimo
# Processing Record 37 of Set 12 | dubrovnik
# Processing Record 38 of Set 12 | kudahuvadhoo
# Processing Record 39 of Set 12 | tautira
# Processing Record 40 of Set 12 | mount isa
# Processing Record 41 of Set 12 | kemijarvi
# Processing Record 42 of Set 12 | alice springs
# Processing Record 43 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 12 | shingu
# Processing Record 45 of Set 12 | yantal
# Processing Record 46 of Set 12 | goderich
# Processing Record 47 of Set 12 | porto walter
# Processing Record 48 of Set 12 | fairbanks
# Processing Record 49 of Set 12 | burica
# City not found. Skipping...
# Processing Record 50 of Set 12 | gdov
# Processing Record 1 of Set 13 | cuiluan
# Processing Record 2 of Set 13 | grand-santi
# Processing Record 3 of Set 13 | outjo
# Processing Record 4 of Set 13 | boyolangu
# Processing Record 5 of Set 13 | visnes
# Processing Record 6 of Set 13 | ishigaki
# Processing Record 7 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 8 of Set 13 | lata
# Processing Record 9 of Set 13 | ellenabad
# Processing Record 10 of Set 13 | verkhoyansk
# Processing Record 11 of Set 13 | samarinda
# Processing Record 12 of Set 13 | galveston
# Processing Record 13 of Set 13 | chimala
# Processing Record 14 of Set 13 | dharchula
# Processing Record 15 of Set 13 | sao filipe
# Processing Record 16 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 13 | basco
# Processing Record 18 of Set 13 | oksfjord
# Processing Record 19 of Set 13 | illintsi
# Processing Record 20 of Set 13 | imeni poliny osipenko
# Processing Record 21 of Set 13 | golden
# Processing Record 22 of Set 13 | morondava
# Processing Record 23 of Set 13 | linhares
# Processing Record 24 of Set 13 | mongo
# Processing Record 25 of Set 13 | tarauaca
# Processing Record 26 of Set 13 | meulaboh
# Processing Record 27 of Set 13 | enshi
# Processing Record 28 of Set 13 | petatlan
# Processing Record 29 of Set 13 | maiduguri
# Processing Record 30 of Set 13 | bandarbeyla
# Processing Record 31 of Set 13 | pascagoula
# Processing Record 32 of Set 13 | fort-shevchenko
# Processing Record 33 of Set 13 | deputatskiy
# Processing Record 34 of Set 13 | tadine
# Processing Record 35 of Set 13 | praia da vitoria
# Processing Record 36 of Set 13 | nakamura
# Processing Record 37 of Set 13 | hellvik
# Processing Record 38 of Set 13 | gorin
# Processing Record 39 of Set 13 | yazd
# Processing Record 40 of Set 13 | hokitika
# Processing Record 41 of Set 13 | kendari
# Processing Record 42 of Set 13 | christchurch
# Processing Record 43 of Set 13 | bongandanga
# Processing Record 44 of Set 13 | kroya
# Processing Record 45 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 13 | bhatkal
# Processing Record 47 of Set 13 | portobelo
# Processing Record 48 of Set 13 | saltillo
# Processing Record 49 of Set 13 | santa cruz del sur
# Processing Record 50 of Set 13 | ust-nera
# Processing Record 1 of Set 14 | betamcherla
# Processing Record 2 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 14 | konosha
# Processing Record 4 of Set 14 | namtsy
# Processing Record 5 of Set 14 | mecca
# Processing Record 6 of Set 14 | joshimath
# Processing Record 7 of Set 14 | salitral
# Processing Record 8 of Set 14 | sinnamary
# Processing Record 9 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 10 of Set 14 | grand gaube
# Processing Record 11 of Set 14 | novoagansk
# Processing Record 12 of Set 14 | dubbo
# Processing Record 13 of Set 14 | broken hill
# Processing Record 14 of Set 14 | port arthur
# Processing Record 15 of Set 14 | bafq
# Processing Record 16 of Set 14 | san carlos de bariloche
# Processing Record 17 of Set 14 | heze
# Processing Record 18 of Set 14 | trinidad
# Processing Record 19 of Set 14 | rio grande
# Processing Record 20 of Set 14 | shimoda
# Processing Record 21 of Set 14 | eyrarbakki
# Processing Record 22 of Set 14 | rocha
# Processing Record 23 of Set 14 | eskilstuna
# Processing Record 24 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 14 | ahuimanu
# Processing Record 26 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 14 | borzya
# Processing Record 28 of Set 14 | shelburne
# Processing Record 29 of Set 14 | sinegorye
# Processing Record 30 of Set 14 | kodinsk
# Processing Record 31 of Set 14 | yumen
# Processing Record 32 of Set 14 | huangchuan
# Processing Record 33 of Set 14 | calvia
# Processing Record 34 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 14 | pishin
# Processing Record 36 of Set 14 | fontem
# Processing Record 37 of Set 14 | gulshat
# City not found. Skipping...
# Processing Record 38 of Set 14 | la ronge
# Processing Record 39 of Set 14 | nanortalik
# Processing Record 40 of Set 14 | botwood
# Processing Record 41 of Set 14 | springbok
# Processing Record 42 of Set 14 | yelkhovka
# Processing Record 43 of Set 14 | razole
# Processing Record 44 of Set 14 | karratha
# Processing Record 45 of Set 14 | port-cartier
# Processing Record 46 of Set 14 | airai
# Processing Record 47 of Set 14 | zheshart
# Processing Record 48 of Set 14 | ayan
# Processing Record 49 of Set 14 | lixourion
# Processing Record 50 of Set 14 | mindelo
# Processing Record 1 of Set 15 | pozo colorado
# Processing Record 2 of Set 15 | anloga
# Processing Record 3 of Set 15 | puga
# Processing Record 4 of Set 15 | darhan
# Processing Record 5 of Set 15 | san isidro
# Processing Record 6 of Set 15 | barre
# Processing Record 7 of Set 15 | iquique
# Processing Record 8 of Set 15 | datong
# Processing Record 9 of Set 15 | naryan-mar
# Processing Record 10 of Set 15 | tiruvottiyur
# City not found. Skipping...
# Processing Record 11 of Set 15 | dianopolis
# City not found. Skipping...
# Processing Record 12 of Set 15 | sao raimundo nonato
# Processing Record 13 of Set 15 | sakakah
# Processing Record 14 of Set 15 | bay-khaak
# Processing Record 15 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 15 | mayo
# Processing Record 17 of Set 15 | kampong chhnang
# Processing Record 18 of Set 15 | kamenka
# Processing Record 19 of Set 15 | ixtapa
# Processing Record 20 of Set 15 | nizwa
# Processing Record 21 of Set 15 | jumla
# Processing Record 22 of Set 15 | aykhal
# Processing Record 23 of Set 15 | katobu
# Processing Record 24 of Set 15 | necochea
# Processing Record 25 of Set 15 | neiafu
# Processing Record 26 of Set 15 | vila real de santo antonio
# Processing Record 27 of Set 15 | mujiayingzi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Saint-Pierre      RE -21.3393   55.4781     78.48        82          75
# 1      Jamestown      US  42.0970  -79.2353     51.53        72         100
# 2         Touros      BR  -5.1989  -35.4608     85.69        63          63
# 3         Kannur      IN  11.8675   75.3576     81.59        84          31
# 4      Hithadhoo      MV  -0.6000   73.0833     82.72        61           7
# 5  Batagay-Alyta      RU  67.8006  130.4114     -9.96        96          93
# 6       Nanakuli      US  21.3906 -158.1547     76.10        68           7
# 7      Saskylakh      RU  71.9167  114.0833    -23.39       100          12
# 8    Clyde River      CA  70.4692  -68.5914     10.63        85         100
# 9     Butaritari      KI   3.0707  172.7902     80.58        81         100
#
#    Wind Speed Current Description
# 0       10.36       broken clouds
# 1        8.05     overcast clouds
# 2       13.11       broken clouds
# 3        3.27    scattered clouds
# 4        2.55           clear sky
# 5        5.82     overcast clouds
# 6       19.71           clear sky
# 7        2.13          few clouds
# 8       16.11          light snow
# 9       15.10          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
